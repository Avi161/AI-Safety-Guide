# %% [markdown]
# # Session 5: Mini-Project — Linear Regression End-to-End (2 hours)
#
# **Goal:** Assemble your **case library** into one class. Session 1: weighted sum (batch @ w). Session 2: center features. Session 3: predictions = X @ w + b, loss, dw. Session 4: gradient descent loop. Here we put them together in `LinearRegressionScratch`.
#
# | Section | Time | Focus |
# |---------|------|-------|
# | Task 5.1 | 1 hr | Complete `LinearRegressionScratch` and fit data |
# | Task 5.2 | 30 min | Experiments & analysis |
# | Anchor: Debug | 25 min | Find and fix buggy gradient update |
# | Anchor: sklearn | 20 min | Compare coefficients and R² with sklearn |
# | Task 5.3 | 35 min | Documentation & reflection |

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import os

# %matplotlib inline

sys.path.insert(0, os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# ---
# ## Task 5.1: Complete the Implementation (1 hour)
#
# **Connection:** The `_compute_gradients` here is the same as in Session 4. The `predict` is the same as Session 3 (X @ w + b). Open `linear_regression_from_scratch.py` and fill in:
# 1. `_compute_cost` — MSE (Session 3)
# 2. `_compute_gradients` — dW and db (Session 4)
# 3. `fit` — training loop (Session 4)
# 4. `predict` — forward pass (Session 3)
# 5. `r_squared` — R² metric
#
# Then come back here to test it.

# %%
from linear_regression_from_scratch import LinearRegressionScratch

# %% [markdown]
# ### Generate Synthetic Data

# %%
np.random.seed(42)

n_samples = 200
n_features = 1

# True relationship: y = 4.5 * x + 2.3 + noise
X = 2 * np.random.rand(n_samples, n_features)
y = 4.5 * X.squeeze() + 2.3 + np.random.randn(n_samples) * 0.8

# Train/test split (80/20)
split = int(0.8 * n_samples)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

print(f"Training set: X={X_train.shape}, y={y_train.shape}")
print(f"Test set:     X={X_test.shape}, y={y_test.shape}")

plt.scatter(X_train, y_train, alpha=0.5, label='Train')
plt.scatter(X_test, y_test, alpha=0.5, label='Test')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Synthetic Data')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### Train the Model

# %%
model = LinearRegressionScratch(learning_rate=0.1, n_iterations=1000)
model.fit(X_train, y_train)

print(f"Learned weights: {model.weights}")
print(f"Learned bias: {model.bias:.4f}")
print(f"True weights: [4.5]")
print(f"True bias: 2.3")

# %% [markdown]
# ### Plot Predictions and Loss Curve

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Left: predictions
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

axes[0].scatter(X_train, y_train, alpha=0.4, label='Train data')
axes[0].scatter(X_test, y_test, alpha=0.4, label='Test data')
x_line = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)
axes[0].plot(x_line, model.predict(x_line), 'r-', linewidth=2, label='Prediction')
axes[0].set_xlabel('X')
axes[0].set_ylabel('y')
axes[0].set_title('Linear Regression Fit')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Right: loss curve
axes[1].plot(model.loss_history)
axes[1].set_xlabel('Iteration')
axes[1].set_ylabel('Cost (MSE)')
axes[1].set_title('Training Loss')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('images/loss_history.png', dpi=150, bbox_inches='tight')
plt.show()

# R-squared
r2_train = model.r_squared(X_train, y_train)
r2_test = model.r_squared(X_test, y_test)
print(f"\nR² (train): {r2_train:.4f}")
print(f"R² (test):  {r2_test:.4f}")

# %% [markdown]
# ---
# ## Task 5.2: Experiments & Analysis (30 min)

# %% [markdown]
# ### Experiment 1: Learning Rate Sensitivity

# %%
learning_rates = [0.001, 0.01, 0.1, 0.5, 1.0]

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for lr in learning_rates:
    m = LinearRegressionScratch(learning_rate=lr, n_iterations=200)
    m.fit(X_train, y_train)
    final_loss = m.loss_history[-1] if m.loss_history else float('inf')
    r2 = m.r_squared(X_test, y_test)
    print(f"LR={lr:<5}: Final Loss={final_loss:.4f}, R²={r2:.4f}")

    axes[0].plot(m.loss_history, label=f'lr={lr}')

axes[0].set_xlabel('Iteration')
axes[0].set_ylabel('Cost')
axes[0].set_title('Loss Curves by Learning Rate')
axes[0].legend()
axes[0].grid(True, alpha=0.3)
axes[0].set_ylim(0, max(10, min(50, axes[0].get_ylim()[1])))

axes[1].set_xlabel('Iteration')
axes[1].set_ylabel('Cost (log scale)')
axes[1].set_title('Loss Curves (Log Scale)')
for lr in learning_rates:
    m = LinearRegressionScratch(learning_rate=lr, n_iterations=200)
    m.fit(X_train, y_train)
    axes[1].semilogy(m.loss_history, label=f'lr={lr}')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Experiment 2: Compare with sklearn

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# sklearn model
sklearn_model = LinearRegression()
sklearn_model.fit(X_train, y_train)

# Our model (well-tuned)
our_model = LinearRegressionScratch(learning_rate=0.1, n_iterations=1000)
our_model.fit(X_train, y_train)

print("=== Comparison ===")
print(f"{'':20s} {'Ours':>12s} {'sklearn':>12s}")
print(f"{'Weight':20s} {our_model.weights[0]:12.4f} {sklearn_model.coef_[0]:12.4f}")
print(f"{'Bias':20s} {our_model.bias:12.4f} {sklearn_model.intercept_:12.4f}")

y_pred_ours = our_model.predict(X_test)
y_pred_sklearn = sklearn_model.predict(X_test)

print(f"{'R² (test)':20s} {r2_score(y_test, y_pred_ours):12.4f} {r2_score(y_test, y_pred_sklearn):12.4f}")

# %% [markdown]
# ### Experiment 3: Multi-Feature Regression

# %%
# Generate multi-feature data: y = 2*x1 + 3*x2 - 1*x3 + 5 + noise
np.random.seed(42)
n = 300
X_multi = np.random.randn(n, 3)
true_weights = np.array([2.0, 3.0, -1.0])
true_bias = 5.0
y_multi = X_multi @ true_weights + true_bias + np.random.randn(n) * 0.5

# Split
X_m_train, X_m_test = X_multi[:240], X_multi[240:]
y_m_train, y_m_test = y_multi[:240], y_multi[240:]

# Fit
model_multi = LinearRegressionScratch(learning_rate=0.01, n_iterations=2000)
model_multi.fit(X_m_train, y_m_train)

print(f"True weights:    {true_weights}")
print(f"Learned weights: {model_multi.weights}")
print(f"True bias:       {true_bias}")
print(f"Learned bias:    {model_multi.bias:.4f}")
print(f"R² (test):       {model_multi.r_squared(X_m_test, y_m_test):.4f}")

# %% [markdown]
# ---
# ## Anchor: Debug a broken implementation [MEDIUM]
#
# **Task:** The code below is a **buggy** one-step gradient update: it has one deliberate bug (wrong sign or wrong formula). Run it, see that loss goes **up** instead of down, then find and fix the bug. Explain in one sentence what was wrong.

# %%
# BUGGY: one step of gradient descent for MSE
np.random.seed(42)
X = np.random.randn(50, 3)
w = np.array([1.0, -0.5, 0.2])
y = X @ w + np.random.randn(50) * 0.2
w_opt = np.zeros(3)
lr = 0.01
pred = X @ w_opt
error = pred - y
dw = (2 / len(y)) * (X.T @ error)
# BUG: one of these lines is wrong — find it!
w_opt = w_opt + lr * dw
loss_after = np.mean((X @ w_opt - y)**2)
loss_before = np.mean((X @ np.zeros(3) - y)**2)
print(f"Loss before: {loss_before:.4f}, after: {loss_after:.4f}")
print("If loss went UP, fix the update rule.")

# %% [markdown]
# ### Your fix and explanation
#
# _Replace the buggy line with the correct update. Explain: we minimize loss so we step in the direction opposite to the gradient._
#
# <details>
# <summary>💡 Click to see fix</summary>
#
# Use `w_opt = w_opt - lr * dw` (minus, not plus). Gradient points uphill; we go downhill.
# </details>

# %%
# YOUR CODE: copy the GD setup from the buggy cell, but use the correct update (minus)
# Run and check that loss goes down.

# %% [markdown]
# ---
# ## Anchor: Compare with sklearn [EASY]
#
# **Task:** Fit the same synthetic data (or the train set from above) with `sklearn.linear_model.LinearRegression`. Compare the coefficients and intercept to your `LinearRegressionScratch` and compare R² on the test set. They should be very close (small numerical differences only).

# %%
from sklearn.linear_model import LinearRegression

# Use your X_train, y_train, X_test, y_test from above
# If not defined, generate again:
np.random.seed(42)
X_sk = np.random.randn(100, 2)
y_sk = X_sk @ np.array([1.5, -0.8]) + 2.0 + np.random.randn(100) * 0.5
X_sk_train, X_sk_test = X_sk[:80], X_sk[80:]
y_sk_train, y_sk_test = y_sk[:80], y_sk[80:]

model_sk = LinearRegression().fit(X_sk_train, y_sk_train)
model_ours = LinearRegressionScratch(learning_rate=0.01, n_iters=2000)
model_ours.fit(X_sk_train, y_sk_train)

print("sklearn coef:", model_sk.coef_, "intercept:", model_sk.intercept_)
print("Ours weights:", model_ours.weights, "bias:", model_ours.bias)
print("sklearn R²:", model_sk.score(X_sk_test, y_sk_test))
print("Ours R²:", model_ours.r_squared(X_sk_test, y_sk_test))

# %% [markdown]
# ### Sensemaking
#
# **Why might your from-scratch R² differ slightly from sklearn's?** (Think: iterations, learning rate, normalization.)

# %% [markdown]
# _Your answer: _

# %% [markdown]
# ---
# ## Task 5.3: Documentation & Reflection (30 min)

# %% [markdown]
# ### Week 1 Completion Checklist
#
# - [ ] NumPy fundamentals (25+ exercises)
# - [ ] Broadcasting visualization
# - [ ] Matrix operations from scratch (3+ implemented)
# - [ ] Gradient descent implementation
# - [ ] Linear regression end-to-end
# - [ ] R-squared > 0.8 on synthetic data

# %% [markdown]
# ### Key Insights
#
# **What I learned about vectorization:**
#
# _Your answer..._
#
# **What I learned about gradient descent:**
#
# _Your answer..._
#
# **What surprised me most:**
#
# _Your answer..._
#
# **What still feels fuzzy:**
#
# _Your answer..._
#
# **Sensemaking:** What from Sessions 1–4 would you **reuse** if we switched to logistic regression? What would **change** (e.g. loss, gradient, prediction function)?
#
# _Your answer: _

# %% [markdown]
# ### Final Checkpoint
#
# Can you implement linear regression from scratch **without looking at your code**?
#
# Try it in the cell below — write the entire `fit` logic from memory.

# %%
# Challenge: Implement linear regression fit from memory
# Given X (n_samples, n_features) and y (n_samples,),
# learn weights and bias using gradient descent.

def linear_regression_from_memory(X, y, lr=0.01, n_iters=1000):
    # YOUR CODE HERE (from memory!)
    pass


# Test it
# w, b = linear_regression_from_memory(X_train, y_train)
# print(f"Weights: {w}, Bias: {b:.4f}")

# %% [markdown]
# ---
# ### Before Week 2
#
# Report back with:
# 1. Your GitHub repo link
# 2. One thing that surprised you
# 3. One concept still fuzzy
# 4. Your linear regression R^2 score
